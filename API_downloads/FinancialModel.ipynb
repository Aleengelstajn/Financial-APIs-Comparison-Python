# %%
''' Libraries ''' 
import requests
import os
import pandas as pd

from urllib.request import urlopen
import functools as ft

# %%
tabla = pd.read_excel('../Merge.xlsx')
columns = ['date', 'symbol'] +list(tabla.tag_finmodprep)
columns.remove('inventory')
columns.append('inventory_x')
columns.append('inventory_y')

# %%
def financial_model(ticker):
    import certifi
    import json
    def get_jsonparsed_data(url):
        """
        Receive the content of ``url``, parse it as JSON and return the object.

        Parameters
        ----------
        url : str

        Returns
        -------
        dict
        """
        response = urlopen(url, cafile=certifi.where())
        data = response.read().decode("utf-8")
        return json.loads(data)

    url_income = f'https://financialmodelingprep.com/api/v3/income-statement/{ticker}?apikey=ba8a6d3ac5e7ca36fc2ee9be73394ef1'
    url_cash = f'https://financialmodelingprep.com/api/v3/cash-flow-statement/{ticker}?apikey=ba8a6d3ac5e7ca36fc2ee9be73394ef1'
    url_balance = f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{ticker}?apikey=ba8a6d3ac5e7ca36fc2ee9be73394ef1'

    income = get_jsonparsed_data(url_income)
    cash = get_jsonparsed_data(url_cash)
    balance = get_jsonparsed_data(url_balance)

    tabla = pd.read_excel('../Merge.xlsx')
    columns = ['date', 'symbol'] +list(tabla.tag_finmodprep)
    columns.remove('inventory')
    columns.append('inventory_x')
    columns.append('inventory_y')

    df_income=pd.DataFrame()
    for j in range(len(income)):
        df= pd.DataFrame(income[j], index=[1])
        df_income = pd.concat([df_income, df], axis=0)
        

    df_cash = pd.DataFrame()
    for i in range(len(cash)):
        df = pd.DataFrame(cash[i], index=[1])
        df_cash = pd.concat([df_cash, df], axis=0)

    df_balance = pd.DataFrame()
    for k in range(len(balance)):
        df = pd.DataFrame(balance[k], index=[1])
        df_balance = pd.concat([df_balance, df], axis=0)

    dfs = [df_cash, df_income, df_balance]
    df_final = ft.reduce(lambda left, right: pd.merge(left, right, on='date'), dfs)
    df_final = df_final[columns]
    return df_final

# %%
financial_model('IBM')
# Out:
# C:\Users\KNL\AppData\Local\Temp\ipykernel_6044\1281914333.py:16: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
#           date symbol   totalAssets  totalLiabilities  \
# 0   2021-12-31    IBM  132001000000      113005000000
# 1   2020-12-31    IBM  155970000000      135245000000
# 2   2019-12-31    IBM  152186000000      131201000000
# 3   2018-12-31    IBM  123382000000      106452000000
# 4   2017-12-31    IBM  125355000000      107631000000
# 5   2016-12-31    IBM  117470000000       99078000000
# 6   2015-12-31    IBM  110491000000       96071000000
# 7   2014-12-31    IBM  117532000000      105518000000
# 8   2013-12-31    IBM  126223000000      103294000000
# 9   2012-12-31    IBM  119213000000      100229000000
# 10  2011-12-31    IBM  116433000000       96197000000
# 11  2010-12-31    IBM  113452000000       90280000000
# 12  2009-12-31    IBM  109022000000       86267000000
# 13  2008-12-31    IBM  109524000000       96059000000
# 14  2007-12-31    IBM  120431000000       91961000000
# 15  2006-12-31    IBM  103234000000       74728000000
# 16  2005-12-31    IBM  105748000000       72650000000
# 17  2004-12-31    IBM  109183000000       79436000000
